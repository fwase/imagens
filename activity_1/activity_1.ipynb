# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np
from collections import defaultdict
from collections import Counter
from helper import show_img, read_img_rgb, increase_brightness, negative, global_histogram

# %matplotlib inline

# %%
image_file = "images/terra_plana.jpeg"

# %%
image = read_img_rgb(image_file)

# %%
show_img(image)

# %% [markdown]
# ### Questão 1

# %%
img_increase_brightness = increase_brightness(image, 50)

# %%
show_img(img_increase_brightness)

# %% [markdown]
# ### Questão 2

# %%
img_negative = negative(image)

# %%
show_img(img_negative)

# %% [markdown]
# ### Questão 3

# %%
img_global_histogram = global_histogram(image, generate_array=False)
