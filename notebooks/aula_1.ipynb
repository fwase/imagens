# %%
import cv2
from matplotlib import pyplot as plt

# %%
image_file = "images/terra_plana.jpeg"

# %%
image = cv2.imread(image_file)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
image.shape
# Out:
# (627, 1200, 3)

# %%
image[0][:25]
# Out:
# array([[56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [56, 33, 37],
#        [60, 33, 37],
#        [60, 33, 37],
#        [60, 33, 37],
#        [60, 33, 37],
#        [60, 33, 37],
#        [60, 33, 37],
#        [60, 33, 37],
#        [60, 33, 37],
#        [61, 34, 38]], dtype=uint8)
